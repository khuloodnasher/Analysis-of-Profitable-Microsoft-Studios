# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Microsoft-Industry-Project" data-toc-modified-id="Microsoft-Industry-Project-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Microsoft Industry Project</a></span></li><li><span><a href="#First:-importing-the-libraries" data-toc-modified-id="First:-importing-the-libraries-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>First: importing the libraries</a></span></li><li><span><a href="#Second:-uploading-the-data" data-toc-modified-id="Second:-uploading-the-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Second: uploading the data</a></span></li><li><span><a href="#Cleaning-the-Data" data-toc-modified-id="Cleaning-the-Data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Cleaning the Data</a></span></li><li><span><a href="#Joining-Three-dataframes" data-toc-modified-id="Joining-Three-dataframes-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Joining Three dataframes</a></span></li><li><span><a href="#Considering-the-last-decade's-movies-2008-2018" data-toc-modified-id="Considering-the-last-decade's-movies-2008-2018-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Considering the last decade's movies 2008-2018</a></span></li><li><span><a href="#plotting-profit-by-year" data-toc-modified-id="plotting-profit-by-year-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>plotting profit by year</a></span></li><li><span><a href="#Plotting-profit-versus--month" data-toc-modified-id="Plotting-profit-versus--month-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Plotting profit versus  month</a></span></li><li><span><a href="#Linear-regression-analysis-of-Production-Budget-versus-profit" data-toc-modified-id="Linear-regression-analysis-of-Production-Budget-versus-profit-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Linear regression analysis of Production Budget versus profit</a></span></li><li><span><a href="#Analyzing-the-profit-versus-the-release-season-in-the-last-decade" data-toc-modified-id="Analyzing-the-profit-versus-the-release-season-in-the-last-decade-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Analyzing the profit versus the release season in the last decade</a></span></li><li><span><a href="#Investigating-the-Profit-through-the-genres-feature" data-toc-modified-id="Investigating-the-Profit-through-the-genres-feature-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Investigating the Profit through the genres feature</a></span></li></ul></li><li><span><a href="#Analyzing-the-Genre-trend-with-regards-to-the-four-seasons" data-toc-modified-id="Analyzing-the-Genre-trend-with-regards-to-the-four-seasons-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Analyzing the Genre trend with regards to the four seasons</a></span><ul class="toc-item"><li><span><a href="#Studying-the-genre-trend-during-Summer,-and-visualize-the-profit" data-toc-modified-id="Studying-the-genre-trend-during-Summer,-and-visualize-the-profit-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Studying the genre trend during Summer, and visualize the profit</a></span></li><li><span><a href="#Studying-the-genre-trend-during-winter/holidays-and-visualize-the-profit" data-toc-modified-id="Studying-the-genre-trend-during-winter/holidays-and-visualize-the-profit-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Studying the genre trend during winter/holidays and visualize the profit</a></span></li><li><span><a href="#Studying-the-genre-trend-during-Fall-season-and-visualize-the-profit" data-toc-modified-id="Studying-the-genre-trend-during-Fall-season-and-visualize-the-profit-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Studying the genre trend during Fall season and visualize the profit</a></span></li><li><span><a href="#Studying-the-genre-trend-during-Spring-and-visualize-the-profit" data-toc-modified-id="Studying-the-genre-trend-during-Spring-and-visualize-the-profit-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Studying the genre trend during Spring and visualize the profit</a></span></li></ul></li><li><span><a href="#Analyzing-the-popularity--to-the-runtime-for-the-highest--genres" data-toc-modified-id="Analyzing-the-popularity--to-the-runtime-for-the-highest--genres-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Analyzing the popularity  to the runtime for the highest  genres</a></span><ul class="toc-item"><li><span><a href="#Visualizing--the-popularity-of-Animation--movies-with-regards-to-the-runtime" data-toc-modified-id="Visualizing--the-popularity-of-Animation--movies-with-regards-to-the-runtime-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Visualizing  the popularity of Animation  movies with regards to the runtime</a></span></li><li><span><a href="#Visualzing--the-popularity-of-scientific-fiction-movies-with-regards-to-the-runtime" data-toc-modified-id="Visualzing--the-popularity-of-scientific-fiction-movies-with-regards-to-the-runtime-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Visualzing  the popularity of scientific fiction movies with regards to the runtime</a></span></li><li><span><a href="#Visualzing--the-popularity-of-Adventure-movies-with-regards-to-the-runtime" data-toc-modified-id="Visualzing--the-popularity-of-Adventure-movies-with-regards-to-the-runtime-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Visualzing  the popularity of Adventure movies with regards to the runtime</a></span></li><li><span><a href="#Visualizing-the-popularity-of-Action-movies-with-regards-to-the-runtime" data-toc-modified-id="Visualizing-the-popularity-of-Action-movies-with-regards-to-the-runtime-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Visualizing the popularity of Action movies with regards to the runtime</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Introduction
# ### Microsoft Industry Project
# In an effort by Microsoft to diversify its investments, they decided to invest in the film industry, and since Microsoft is keen on implementing its plans professionally, they have decided to employ a data scientist  whose job is to explore the data of the movie industry, analyze it and set recommendations based on the outcomes of the analysis.
#
# The following Questions were addressed:
#
# 1- How has the movie industry changed in the last decade from 2008-2018?
#
# 2- What production budget range is more profitable for movies?
#
# 3- Which season is the most profitable?
#
# 4- What are the most successful genres?
#
# 5- Which genre is the most profitable for each season?
#
# 6- Does the runtime have any effect on the popularity of the genre?

# %% [markdown]
# ### First: importing the libraries

# %%
# Importing the Libraries

import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## To remove warnings
import warnings
warnings.filterwarnings("ignore")

# %%
## To display  all the interactive output without using the print function
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Second: uploading the data

# %%
# Uploading the Data Sheet and creating a Data Frame
df_tn = pd.read_csv('tn.movie_budgets.csv.gz')
df_tn.head()
df_tn.info()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
# ...

# %% [markdown]
# ### Cleaning the Data

# %%
# formatting the relase date to a datetime format(YY--mm-dd) 
df_tn['release_date'] = pd.to_datetime(df_budget['release_date'], infer_datetime_format=True)
df_tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Replacing the '$' sign
df_tn['production_budget'] = df_tn['production_budget'].str.replace('$','')
df_tn['domestic_gross'] = df_tn['domestic_gross'].str.replace('$', '')
df_tn['worldwide_gross'] = df_tn['worldwide_gross'].str.replace('$', '')
df_tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0       425,000,000    760,507,625   2,776,345,279
# 1       410,600,000    241,063,875   1,045,663,875
# 2       350,000,000     42,762,350     149,762,350
# 3       330,600,000    459,005,868   1,403,013,963
# 4       317,000,000    620,181,382   1,316,721,747

# %%
# Delete commas from "production_budget,domestic_gross and worldwide_gross columns"
df_tn['production_budget'] = df_tn['production_budget'].str.replace(',', '')
df_tn['domestic_gross'] = df_tn['domestic_gross'].str.replace(',', '')
df_tn['worldwide_gross'] = df_tn['worldwide_gross'].str.replace(',', '')
df_tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0         425000000      760507625      2776345279
# 1         410600000      241063875      1045663875
# 2         350000000       42762350       149762350
# 3         330600000      459005868      1403013963
# 4         317000000      620181382      1316721747

# %%
# lowering case the movie column

df_tn['movie'] = df_tn['movie'].str.lower()
df_tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#   production_budget domestic_gross worldwide_gross
# 0         425000000      760507625      2776345279
# 1         410600000      241063875      1045663875
# 2         350000000       42762350       149762350
# 3         330600000      459005868      1403013963
# 4         317000000      620181382      1316721747

# %%
# changing the type of the production budget,domestic gross and worldwide gross to mumeric as integer
df_tn['production_budget'] = df_tn['production_budget'].astype('int64')
df_tn['domestic_gross'] = df_tn['domestic_gross'].astype('int64')
df_tn['worldwide_gross'] = df_tn['worldwide_gross'].astype('int64')

# Dropping unneeded columns
df_budget = df_tn.drop(columns = ['id'])
df_budget.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       avatar
# 1   2011-05-20  pirates of the caribbean: on stranger tides
# 2   2019-06-07                                 dark phoenix
# 3   2015-05-01                      avengers: age of ultron
# 4   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
# Calcualting the revenue, and profit and adding them to the dataframe
df_tn['Revenue'] = df_tn['domestic_gross'] + df_tn['worldwide_gross']
df_tn['Profit'] = df_tn['Revenue'] - df_tn['production_budget']
df_tn['profit_percentage']=(df_tn['production_budget']/df_tn['Profit'])*100
df_tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross  worldwide_gross     Revenue      Profit  \
# 0          425000000       760507625       2776345279  3536852904  3111852904
# 1          410600000       241063875       1045663875  1286727750   876127750
# 2          350000000        42762350        149762350   192524700  -157475300
# 3          330600000       459005868       1403013963  1862019831  1531419831
# 4          317000000       620181382       1316721747  1936903129  1619903129
#
#    profit_percentage
# 0          13.657458
# 1          46.865312
# 2        -222.257078
# ...

# %%
# removing duplicated values from the dataframe
df_tn.drop_duplicates(subset=None, keep='first')
df_tn.duplicated().value_counts()
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       avatar
# 1      2   2011-05-20  pirates of the caribbean: on stranger tides
# 2      3   2019-06-07                                 dark phoenix
# 3      4   2015-05-01                      avengers: age of ultron
# 4      5   2017-12-15            star wars ep. viii: the last jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       red 11
# 5778  79   1999-04-02                                    following
# 5779  80   2005-07-13                return to the land of wonders
# 5780  81   2015-09-29                         a plague so pleasant
# 5781  82   2005-08-05                            my date with drew
#
#       production_budget  domestic_gross  worldwide_gross     Revenue  \
# 0             425000000       760507625       2776345279  3536852904
# ...

# %%
# Uploading the Data Sheet and creating a Data Frame for the title_basics file
df_genres = pd.read_csv('imdb.title.basics.csv.gz')
df_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
# removing duplicated values from the dataframe
df_genres.drop_duplicates(subset=None, keep='first')
df_genres.duplicated().value_counts()
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
# Renaming the column original_title
df_genres = df_genres.rename(columns={'original_title' : 'movie'})
df_genres['movie'] = df_genres['movie'].str.lower()
df_genres.head()
# Out:
#       tconst                    primary_title                       movie  \
# 0  tt0063540                        Sunghursh                   sunghursh
# 1  tt0066787  One Day Before the Rainy Season             ashad ka ek din
# 2  tt0069049       The Other Side of the Wind  the other side of the wind
# 3  tt0069204                  Sabse Bada Sukh             sabse bada sukh
# 4  tt0100275         The Wandering Soap Opera       la telenovela errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#Extracting the release year from the release date
df_budget['release_year'] = pd.DatetimeIndex(df_budget['release_date']).year
df_budget.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       avatar
# 1   2011-05-20  pirates of the caribbean: on stranger tides
# 2   2019-06-07                                 dark phoenix
# 3   2015-05-01                      avengers: age of ultron
# 4   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross  worldwide_gross  release_year
# 0          425000000       760507625       2776345279          2009
# 1          410600000       241063875       1045663875          2011
# 2          350000000        42762350        149762350          2019
# 3          330600000       459005868       1403013963          2015
# 4          317000000       620181382       1316721747          2017

# %%
# Creating Data Frame for the tmdb_movies file
df_tmdb_movies = pd.read_csv('tmdb.movies.csv.gz')
df_tmdb_movies = df_tmdb_movies.rename(columns={'original_title' : 'movie'}) # rename the column
df_tmdb_movies ['movie'] = df_tmdb_movies['movie'].str.lower()
df_tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                           movie  popularity release_date  \
# 0  harry potter and the deathly hallows: part 1      33.533   2010-11-19
# 1                      how to train your dragon      28.734   2010-03-26
# 2                                    iron man 2      28.515   2010-05-07
# 3                                     toy story      28.005   1995-11-22
# 4                                     inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
# Removing duplicates
df_tmdb_movies.drop_duplicates(subset=None, keep='first')
df_tmdb_movies.info()
df_tmdb_movies.isna().sum() ## checking Nan values
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                               movie  popularity release_date  \
# 0      harry potter and the deathly hallows: part 1      33.533   2010-11-19
# ...

# %%
# Dropping unneeeded columns
df_tmdb_movies = df_tmdb_movies.drop(columns = ['Unnamed: 0','id','genre_ids','title','vote_count','original_language'])
df_tmdb_movies.head()
# Out:
#                                           movie  popularity release_date  \
# 0  harry potter and the deathly hallows: part 1      33.533   2010-11-19
# 1                      how to train your dragon      28.734   2010-03-26
# 2                                    iron man 2      28.515   2010-05-07
# 3                                     toy story      28.005   1995-11-22
# 4                                     inception      27.920   2010-07-16
#
#    vote_average
# 0           7.7
# 1           7.7
# 2           6.8
# 3           7.9
# 4           8.3

# %%
#Extracting the release year fromt the release date
df_tmdb_movies['release_year'] = pd.DatetimeIndex(df_tmdb_movies['release_date']).year
df_tmdb_movies.head(10)
# Out:
#                                                movie  popularity release_date  \
# 0       harry potter and the deathly hallows: part 1      33.533   2010-11-19
# 1                           how to train your dragon      28.734   2010-03-26
# 2                                         iron man 2      28.515   2010-05-07
# 3                                          toy story      28.005   1995-11-22
# 4                                          inception      27.920   2010-07-16
# 5  percy jackson & the olympians: the lightning t...      26.691   2010-02-11
# 6                                             avatar      26.526   2009-12-18
# 7                                        toy story 3      24.445   2010-06-17
# 8                                      despicable me      23.673   2010-07-09
# 9                                           megamind      22.855   2010-11-04
#
#    vote_average  release_year
# 0           7.7          2010
# 1           7.7          2010
# ...

# %% [markdown]
# ### Joining Three dataframes

# %%
df_merged = df_genres.merge(df_tmdb_movies, on='movie').merge(df_tn, on='movie')
df_merged.drop_duplicates(subset=None, keep='first',inplace=True)
df_merged.duplicated().value_counts()
# Out:
# False    3804
# dtype: int64

# %%
# Dropping unneeded columns,''
df_merged = df_merged.drop(columns = ['release_date_x','vote_average','tconst','primary_title','start_year','id'])
# rename the coloumn
df_merged = df_merged.rename(columns={'release_date_y' : 'release_date'})

# %%
# Dropping duplicate columns based on movie name and release date
df_merged=df_merged.drop_duplicates(subset=['movie','release_date'], keep='first')

# %%
## checking duplicated values
df_merged.info()
df_merged.duplicated().value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1862 entries, 0 to 4063
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              1862 non-null   object
#  1   runtime_minutes    1813 non-null   float64
#  2   genres             1851 non-null   object
#  3   popularity         1862 non-null   float64
#  4   release_year       1862 non-null   int64
#  5   release_date       1862 non-null   datetime64[ns]
#  6   production_budget  1862 non-null   int64
#  7   domestic_gross     1862 non-null   int64
#  8   worldwide_gross    1862 non-null   int64
#  9   Revenue            1862 non-null   int64
#  10  Profit             1862 non-null   int64
#  11  profit_percentage  1862 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(2)
# memory usage: 189.1+ KB
# False    1862
# dtype: int64

# %% [markdown]
# ### Considering the last decade's movies 2008-2018

# %%
df_new=df_merged[df_merged['release_year']>=2008]
df_merged=df_new[df_new['release_year']<=2018]
df_merged['release_year'].max() # checking the highest year
df_merged['release_year'].min() # checking the lowest year
df_merged['Profit'].max() # checking the maximum profit
df_merged['Profit'].min() # checking the minimum profit
df_merged = df_merged.sort_values(by='Profit', ascending=False) #Sorting the value by Profit column in descending order
df_percentage=df_merged.sort_values(by='profit_percentage', ascending=False)
df_percentage.head(10)
df_merged.info()
df_merged.head()
# Out:
# 2018
# 2008
# 2426949682
# -90000000
#                movie  runtime_minutes     genres  popularity  release_year  \
# 3244       dragonfly             80.0      Drama       0.664          2016
# 3244       dragonfly             80.0      Crime       0.664          2016
# 3244       dragonfly             80.0   Thriller       0.664          2016
# 581         repo men            111.0     Action      12.437          2010
# 581         repo men            111.0      Crime      12.437          2010
# 581         repo men            111.0     Sci-Fi      12.437          2010
# 1532  mortal engines            128.0  Adventure      40.095          2018
# 1532  mortal engines            128.0     Action      40.095          2018
# 1532  mortal engines            128.0    Fantasy      40.095          2018
# 2814   dead man down            118.0     Action      10.349          2013
#
#      release_date  production_budget  domestic_gross  worldwide_gross  \
# ...

# %%
df_merged.isna().sum()
# Out:
# movie                 0
# runtime_minutes      45
# genres               11
# popularity            0
# release_year          0
# release_date          0
# production_budget     0
# domestic_gross        0
# worldwide_gross       0
# Revenue               0
# Profit                0
# profit_percentage     0
# dtype: int64

# %%
#dropping null values from 'genres column' and ''runtime_minutes''
df_merged = df_merged.dropna(subset=['genres'])
df_merged = df_merged.dropna(subset=['runtime_minutes'])

# %%
#Extracting the month name from the release date and put it in word format with first three letters
df_merged['Month'] = pd.to_datetime(df_merged['release_date'], format='%m').dt.month_name().str.slice(stop=3)
df_merged['release_month'] = pd.DatetimeIndex(df_merged['release_date']).month ## extracting date

#Splitting the genres category
df_merged['genres']=df_merged['genres'].str.split(",",3)
df_merged=df_merged.explode('genres')
df_merged.info()

#Sorting the value by Profit column
df_merged = df_merged.sort_values(by='Profit', ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4458 entries, 3804 to 3971
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              4458 non-null   object
#  1   runtime_minutes    4458 non-null   float64
#  2   genres             4458 non-null   object
#  3   popularity         4458 non-null   float64
#  4   release_year       4458 non-null   int64
#  5   release_date       4458 non-null   datetime64[ns]
#  6   production_budget  4458 non-null   int64
#  7   domestic_gross     4458 non-null   int64
#  8   worldwide_gross    4458 non-null   int64
#  9   Revenue            4458 non-null   int64
#  10  Profit             4458 non-null   int64
#  11  profit_percentage  4458 non-null   float64
#  12  Month              4458 non-null   object
#  13  release_month      4458 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(3)
# memory usage: 522.4+ KB

# %%
# set season function according to release_month: Winetr  is the month of December-February,Spring:March-May
# Summer: June-August,Fall:September-November


def seasons(season):
    return season.map(lambda x: "winter/holiday" if x > 11 or x < 3
                      else ("spring" if x >= 3 and x < 6
                            else ("summer" if x > 5 and x < 9
                                  else ("Fall"))))

# %%
# applying the seasons function and adding season column to assess if release season affects profit
df_merged['release_season'] = seasons(df_merged['release_month'])

df_merged['release_season'].value_counts()
# Out:
# Fall              1208
# summer            1113
# winter/holiday    1085
# spring            1052
# Name: release_season, dtype: int64

# %%
# set runtime in hour function according to runtime_minutes column: runtime is defined as less than one hour if < 60 minutes 
# 1-2 hours if 60>runtime>120 and  above 2 hours with any time else

def run_time(runtime):
    return runtime.map(lambda y: "Less than 1 hour" if y < 60
                                         else ("1-2 hours" if y > 60 and y < 120
                                         else ("More than 2 hours")))

df_merged['runtime_hour'] = run_time(df_merged['runtime_minutes']) # applying the runtime function to the dataframe
                                         
df_merged['runtime_hour'].value_counts()  

df_merged.head()
# Out:
# 1-2 hours            3533
# More than 2 hours     874
# Less than 1 hour       51
# Name: runtime_hour, dtype: int64
#                        movie  runtime_minutes     genres  popularity  \
# 3804  avengers: infinity war            149.0     Action      80.773
# 3804  avengers: infinity war            149.0     Sci-Fi      80.773
# 3804  avengers: infinity war            149.0  Adventure      80.773
# 11            jurassic world            124.0     Action      20.709
# 11            jurassic world            124.0     Sci-Fi      20.709
#
#       release_year release_date  production_budget  domestic_gross  \
# 3804          2018   2018-04-27          300000000       678815482
# 3804          2018   2018-04-27          300000000       678815482
# 3804          2018   2018-04-27          300000000       678815482
# 11            2015   2015-06-12          215000000       652270625
# 11            2015   2015-06-12          215000000       652270625
#
# ...

# %%
df_merged['genres'].nunique()
# Out:
# 21

# %%
df_merged['genres'].value_counts()
# Out:
# Drama          888
# Comedy         572
# Action         475
# Adventure      368
# Thriller       322
# Crime          277
# Horror         232
# Romance        224
# Sci-Fi         154
# Biography      151
# Mystery        142
# Fantasy        139
# Family         113
# Animation      107
# Documentary     93
# History         59
# Music           53
# Sport           35
# War             26
# Western         15
# Musical         13
# Name: genres, dtype: int64

# %% [markdown]
# ### plotting profit by year

# %%
# profit versus release year
plt.figure(figsize=(15,8))
plt.style.use('dark_background')
ax1=sns.stripplot(x=df_merged.release_year, y=df_merged.Profit/1000000000, data = df_merged)
ax1.set_title('Profit vs Release Year',fontsize=20,color='blue')
ax1.set_xlabel('Release Year',fontsize=15,color='blue')
ax1.set_ylabel('Profit (billion USD)',fontsize=15,color='blue');

# %% [markdown]
# ### Plotting profit versus  month

# %%
### Profit versus release month
df_merged = df_merged.sort_values(by='release_month', ascending=True)
sns.set(rc={'figure.figsize':(15,7)}) #Setting the Chart area size
h=sns.barplot(x=df_merged.Month,y=df_merged.Profit/1000000,color="r")
h.set_xticklabels(h.get_xticklabels(),rotation=90)
h.set_title("Profit by Month", color='black', fontsize=20) 
h.set(xlabel='Month', ylabel='Profit (million USD)')
plt.show();

# %% [markdown]
# ###  Linear regression analysis of Production Budget versus profit

# %%
## Linear regression analyses of Production Budget versus profit
plt.figure(figsize=(15,8))
plt.style.use('dark_background')
sns.regplot( x=df_merged.production_budget/1000000, y=df_merged.Profit/1000000000, data=df_merged)
plt.title('Correlation Between Production Budget and Profit', fontsize=20,color='blue')
plt.ylabel('Profit (billion USD)', color='blue')
plt.xlabel('Production Budget (million USD)',color='blue');

# %% [markdown]
# ### Analyzing the profit versus the release season in the last decade

# %%
## Grouping by release year, and release season and slicing by the mean of the profit  
## line plot visualizing of the profit versus release season and release year
df_season_profit=(df_merged.groupby(['release_year','release_season'])['Profit'].mean()/1000000).sort_values(ascending=False)
df_season_profit.head()
sns.set_context('talk')
fig = df_season_profit.unstack().plot(kind = 'line')
plt.title('Release Season and Year vs Profit',fontsize=18,color='white')
plt.ylabel('Profit (million USD)',fontsize=15)
fig.legend(loc='lower right', frameon=False);

# %% [markdown]
# ### Investigating the Profit through the genres feature

# %%
## Barh plot of profit versus genres
## new dataframe created by grouping by genres and slicing by the  mean of profit in descendant order
df_generes = (df_merged.groupby(['genres'])['Profit'].mean()/1000000).sort_values(ascending=False)
df_generes.head()
plt.style.use('dark_background')
fig = df_generes.plot(kind = 'barh',color='brown')
plt.title('Genre vs Profit',fontsize=18,color='white')
plt.xlabel('Profit (million USD)',fontsize=15)
plt.ylabel('Genre',fontsize=18)
plt.rcParams["figure.figsize"] = [15, 8];

# %%
##Analyzing the profit to the genres by violin plot and stripplot

df_genre_profit=df_merged[['genres','Profit']]
df_genre_profit.info()
df_genre_profit.sort_values(by=['Profit'],ascending=False)
plt.figure(figsize=(15,8))
sns.set_style('darkgrid')
plt.title("Profit by Genre", fontsize=20)
# Violin plot
ax=sns.violinplot(x=df_genre_profit.genres, y=df_genre_profit.Profit/1000000000, data=df_genre_profit)
# stripplot
ax=sns.stripplot(x=df_genre_profit.genres, y=df_genre_profit.Profit/1000000000, data=df_genre_profit)
plt.xlabel('Genres',fontsize=15,color='blue')
plt.ylabel('Profit (Billion USD)',fontsize=15,color='blue')
plt.xticks(rotation=90);
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4458 entries, 935 to 3971
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genres  4458 non-null   object
#  1   Profit  4458 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 264.5+ KB

# %% [markdown]
# ## Analyzing the Genre trend with regards to the four seasons

# %% [markdown]
# ### Studying the genre trend during Summer, and visualize the profit

# %%
# new dataframe was created for summer and was grouped by genres and sliced by the mean of profit and sorted in descending order
# Visualize profit versus genres in the summer by barplot
df_summer=df_merged[(df_merged['Profit']) & (df_merged['release_season']=='summer')]
df_summer_plot = (df_summer.groupby(['genres'])['Profit'].mean()/1000000).sort_values(ascending=False)
plt.style.use('dark_background')
fig1 = df_summer_plot.plot(kind = 'bar',color='blue')
plt.title('Genres vs Profitin Summer')
plt.xlabel('Genres')
plt.ylabel('Profit (million USD)')
plt.rcParams["figure.figsize"] = [5, 5];

# %% [markdown]
# ### Studying the genre trend during winter/holidays and visualize the profit

# %%
# new dataframe was created for winter/holiday and was grouped by genres and sliced by the mean of profit and sorted in descending order
#  Visualize profit versus genres in the winter/holiday by barplot
df_winter=df_merged[(df_merged['Profit']) & (df_merged['release_season']=='winter/holiday')]
df_winter_plot = (df_winter.groupby(['genres'])['Profit'].mean()/1000000).sort_values(ascending=False)
fig2 = df_winter_plot.plot(kind = 'bar',color='blue')
plt.style.use('dark_background')
plt.title('Genres vs Profit in Winter/Holiday')
plt.xlabel('Genres')
plt.ylabel('Profit (million USD)')
plt.rcParams["figure.figsize"] = [15, 5];

# %% [markdown]
# ### Studying the genre trend during Fall season and visualize the profit

# %%
# new dataframe was created for Fall and was grouped by genres and sliced by the mean of profit and sorted in descending order
# Visualize  profit versus genres in Fall  by barplot
df_fall=df_merged[(df_merged['Profit']) & (df_merged['release_season']=='Fall')]
df_fall_plot = (df_fall.groupby(['genres'])['Profit'].mean()/1000000).sort_values(ascending=False)
plt.style.use('dark_background')
fig3 = df_fall_plot.plot(kind = 'bar',color='blue')
plt.title('Genre vs Profit in Fall')
plt.xlabel('Genres')
plt.ylabel('Profit (million USD)')
plt.rcParams["figure.figsize"] = [15, 6];

# %% [markdown]
# ### Studying the genre trend during Spring and visualize the profit

# %%
# new dataframe was created for Spring and was grouped by genres and sliced by the mean of profit and sorted in descending order
#  Visualize profit versus genres in the Spring by barplot
df_spring=df_merged[(df_merged['Profit']) & (df_merged['release_season']=='spring')]
df_spring_plot = (df_spring.groupby(['genres'])['Profit'].mean()/1000000).sort_values(ascending=False)
plt.style.use('dark_background')
fig4 = df_spring_plot.plot(kind = 'bar',color='blue')
plt.title('Genre vs Profit in Spring')
plt.xlabel('Genres')
plt.ylabel('Profit (million USD)')
plt.rcParams["figure.figsize"] = [15, 6];

# %% [markdown]
# ## Analyzing the popularity  to the runtime for the highest  genres

# %% [markdown]
# ###  Visualizing  the popularity of Animation  movies with regards to the runtime

# %%
# stripplot of popularity to runtime for Animation movies
# new dataframe is created where genere is animation
df_animation=df_merged[(df_merged['genres']=='Animation')]
plt.style.use('dark_background')
ax = sns.stripplot(x="runtime_hour", y="popularity", data=df_animation)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);
ax.set_title('Popularity  to Runtime for Animation Movies',fontsize=18,color='white')
ax.set_xlabel('Runtime(hour)',fontsize=15,color='white')
ax.set_ylabel('popularity',fontsize=15,color='white');

# %% [markdown]
# ###  Visualzing  the popularity of scientific fiction movies with regards to the runtime

# %%
# stripplot of popularity to runtime for science fiction movies
# new dataframe is created where genere is science fiction
df_sci_fi=df_merged[(df_merged['genres']=='Sci-Fi')]
plt.style.use('dark_background')
ax = sns.stripplot(x="runtime_hour", y="popularity", data=df_sci_fi)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);
ax.set_title('Popularity by Runtime for Sci-Fi Movies',fontsize=18,color='white')
ax.set_xlabel('Runtime(hour)',fontsize=15,color='white')
ax.set_ylabel('Popularity',fontsize=15,color='white');

# %% [markdown]
# ###  Visualzing  the popularity of Adventure movies with regards to the runtime

# %%
# stripplot of popularity to runtime for Adventure movies
# new dataframe is created where genere is Adventure
df_adventure=df_merged[(df_merged['genres']=='Adventure')]
plt.style.use('dark_background')
ax = sns.stripplot(x="runtime_hour", y="popularity", data=df_adventure)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);
ax.set_title('Popularity by Runtime for Adventure Movies',fontsize=18,color='white')
ax.set_xlabel('Runtime(hour)',fontsize=15,color='white')
ax.set_ylabel('Popularity',fontsize=15,color='white');

# %% [markdown]
# ### Visualizing the popularity of Action movies with regards to the runtime

# %%
# stripplot of popularity to runtime for Action movies
# new dataframe is created where genere is animation
df_animation=df_merged[(df_merged['genres']=='Action')]
plt.style.use('dark_background')
ax = sns.stripplot(x="runtime_hour", y="popularity", data=df_animation)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);
ax.set_title('Popularity  to Runtime for Action Movies',fontsize=18,color='white')
ax.set_xlabel('Runtime(hour)',fontsize=15,color='white')
ax.set_ylabel('popularity',fontsize=15,color='white');

# %% [markdown]
# ### Conclusion
# The analysis proves that the movie industry was a good investment in the last 10 years.
# The recommendations go as follows:
# - A Successful  production budget is between 150 US million Dollars to 250 US million Dollars.
# -  Summer is the most profitable season for releasing movies.
# - The best suggested runtime is over one hour and less than two hours.
# - Animation, Scientific fiction, Action, and  Adventure are the most popular profitable genres.
# -  Animation movies do best if be run greater than one hour but less than two hours so children will not be bored and they are best to be released in summer time when school is off.
